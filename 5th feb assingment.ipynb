# %%
# ANSWER 1) 
# In object-oriented programming (OOP), a class is a blueprint or template for creating objects. It defines a set of attributes (data members) and methods (member functions) that an object of that class can have.
# An object, on the other hand, is an instance of a class that has been created and instantiated using the class blueprint. It has its own set of values for the data members and can invoke the methods defined in the class.

# For example:
   # consider a class called 'Car'. The 'Car' class could have attributes such as 'color', 'make', 'model' and 'year'.  When an object is instantiated from the Car class, it would have its own unique set of values for the attributes (e.g. color = "red", make = "Toyota", model = "Corolla", year = 2022).
# In this example, Car is the class and car is the object that has been instantiated from that class. By defining the class once, you can create multiple objects (e.g. car1, car2, car3, etc.) with the same attributes and methods, but with different values for those attributes. This is one of the main benefits of using OOP – it allows you to create reusable code that can be easily customized to create multiple instances of the same type of object.

# %%
# ANSWER 2)
# The four pillars of Object-Oriented Programming (OOP) are:
    
    #1) Encapsulation.
    #2) Abstraction.
    #3) Inheritance.
    #4) Polymorphism.

# %%
# ANSWER 3)
# In Python, the __init__() function is a special method that is called automatically when an object of a class is created. It is used to initialize the attributes or properties of the object. 
# The purpose of the __init__() method is to provide a way to customize the creation of an object with specific initial values for its attributes.

# For example, let's say we want to create a class called square to represent square. The class might have two attributes: length and width. We can define the '__init__()' method to take two arguments, length and width, and use them to initialize the length and width attributes of the object:
# class square:
#    def __init__(self, length, width):
#        self.length = length
#        self.width = width

# %%
# ANSWER 4)
# In object-oriented programming (OOP), self is a reference variable used to refer to the current instance of a class.
# It is a convention in Python to use self as the first parameter in the definition of instance methods. self is not a reserved keyword in Python, but it is a widely accepted convention in the Python community.

# Using self allows us to access the attributes and methods of an instance of a class from within that instance. 
# When we create an object of a class, we can use the self keyword to refer to that object's instance variables and methods.

# For example, let's say we have a class called Person with an instance method called greet that takes a name parameter. 
# Inside the greet method, we can use self to refer to the current instance of the Person class and access its attributes:
#    class Person:
#    def __init__(self, name):
#       self.name = name

#    def greet(self):
#        print("Hello, my name is", self.name)

# %%
# ANSWER 5)

#Inheritance is a key concept in object-oriented programming that allows us to create a new class that is a modified version of an existing class. The new class inherits the properties and methods of the existing class and can add new features or modify existing ones. 
#Inheritance promotes code reusability and reduces code duplication by allowing us to create new classes based on existing ones.

#There are four types of inheritance in object-oriented programming:
# 1)  Single Inheritance: In single inheritance, a subclass inherits from a single superclass. This is the simplest and most common type of inheritance. For example:

#class Animal:
#    def __init__(self, name):
#        self.name = name
#
#    def speak(self):
#      print("I am an animal")

#class Cat(Animal):
#    def __init__(self, name):
#        super().__init__(name)

#    def speak(self):
#        print("Meow")
        
#2) Multiple Inheritance: In multiple inheritance, a subclass inherits from multiple superclasses. For example:

#class A:
#    def foo(self):
#        print("A")

#class B:
#    def foo(self):
#        print("B")

#class C(A, B):
#    pass

#3) Multilevel Inheritance: In multilevel inheritance, a subclass inherits from a superclass, which itself inherits from another superclass. For example:

#class Animal:
#    def __init__(self, name):
#        self.name = name

#    def speak(self):
#        print("I am an animal")

#class Mammal(Animal):
#    def __init__(self, name):
#        super().__init__(name)

#    def run(self):
#       print("I can run")

#class Cat(Mammal):
#    def __init__(self, name):
#        super().__init__(name)

#   def speak(self):
#        print("Meow")  
        
#4) Hierarchical Inheritance: In hierarchical inheritance, multiple subclasses inherit from a single superclass. For example:
    
#class Animal:
#    def __init__(self, name):
#        self.name = name

#    def speak(self):
#        print("I am an animal")

#class Cat(Animal):
#    def __init__(self, name):
#        super().__init__(name)

#    def speak(self):
#        print("Meow")

#class Dog(Animal):
#    def __init__(self, name):
#        super().__init__(name)

#    def speak(self):
#        print("Woof").
